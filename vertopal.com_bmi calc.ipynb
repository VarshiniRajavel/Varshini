# %% [markdown]
# h=float(input(“Enter your Height in meters:” )) w=float(input(“Enter
# your Weight in kg:” )) BMI=w/(h\*h) print (“BMI Calculated is:”,BMI)
# if(BMI\>0): if(BMI\<18.5):
# print(" Need to increase your weight“) elif(BMI\>18.5) and (BMI\<24.9):
# print(” Congrats you are Normal weight“) elif(BMI\>25) and (BMI\<29.9):
# print(” Sorry! you are Over weight“) elif(BMI\>30): print(”Immediately
# need to reduce weight atleast for your health,obesity“) else:
# print(”Something went wrong try again")
#
# h=float(input(“Enter your Height in meters:” )) w=float(input(“Enter
# your Weight in kg:” )) BMI=w/(h\*h) print (“BMI Calculated is:”,BMI)
# if(BMI\>0): if(BMI\<18.5):
# print(" Need to increase your weight“) elif(BMI\>18.5) and (BMI\<24.9):
# print(” Congrats you are, Normal weight“) elif(BMI\>25) and (BMI\<29.9):
# print(” Sorry! you are Over weight“) elif(BMI\>30): print(”Immediately
# need reduce weight atleast for your health,obesity“) else:
# print(”Something went wrong try again")
#
# h=float(input(“Enter your Height in meters:” )) w=float(input(“Enter
# your Weight in kg:” )) BMI=w/(h\*h) print (“BMI Calculated is:”,BMI)
# if(BMI\>0): if(BMI\<18.5):
# print(" Need to increase your weight“) elif(BMI\>18.5) and (BMI\<24.9):
# print(” Congrats you are Normal weight“) elif(BMI\>25) and (BMI\<29.9):
# print(” Sorry! you are Over weight“) elif(BMI\>30): print(”Immediately
# need reduce weight atleast for your health, obesity“) else:
# print(”Something went wrong try again")
#
# h=float(input(“Enter your Height in meters:” )) w=float(input(“Enter
# your Weight in kg:” )) BMI=w/(h\*h) print (“BMI Calculated is:”,BMI)
# if(BMI\>0): if(BMI\<18.5):
# print(" Need to increase your weight“) elif(BMI\>18.5) and (BMI\<24.9):
# print(” Congrats you are Normal weight“) elif(BMI\>25) and (BMI\<29.9):
# print(” Sorry! you are Over weight“) elif(BMI\>30): print(”Immediately
# need reduce weight atleast for your health,obesity“) else:
# print(”Something went wrong try again")
#
# h=float(input(“Enter your Height in meters:” )) w=float(input(“Enter
# your Weight in kg:” )) BMI=w/(h\*h) print (“BMI Calculated is:”,BMI)
# if(BMI\>0): if(BMI\<18.5):
# print(" Need to increase your weight“) elif(BMI\>18.5) and (BMI\<24.9):
# print(” Congrats you are Normal weight“) elif(BMI\>25) and (BMI\<29.9):
# print(” Sorry! you are Over weight“) elif(BMI\>30): print(”Immediately
# need reduce weight atleast for your health,obesity“) else:
# print(”Something went wrong try again")
